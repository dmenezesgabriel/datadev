# %% [markdown]
# # Mlflow

# %% [markdown]
# Run the Mlflow UI:
#
# ```sh
# uv run --with mlflow==3.7.0 mlflow ui
# ```

# %% [markdown]
# Install packages

# %%
# !uv pip install -q \
    mlflow==3.7.0

# %% [markdown]
# Import packages

# %%
import mlflow

# %% [markdown]
# Set tracking URI

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")
